# %% [markdown]
# ## Data science final project

# %% [markdown]
# ## Prediction of E-commerce Product delivery

# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r'C:\Users\Aishu\Desktop\Data_Science_Final_Project\Prediction_of_E-commerce_Product_Delivery\E_Commerce.csv')

# %%
df.head(10)
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_Rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
# 5   6               F           Flight                    3                1
# 6   7               D           Flight                    3                4
# 7   8               F           Flight                    4                1
# 8   9               A           Flight                    3                4
# 9  10               B           Flight                    3                2
#
#    Cost_of_the_Product  Prior_purchases Order_Priority  Gender  Discount  \
# 0                  177                3            low  Female        44
# 1                  216                2            low    Male        59
# 2                  183                4            low    Male        48
# 3                  176                4         medium    Male        10
# 4                  184                3         medium  Female        46
# 5                  162                3         medium  Female        12
# 6                  250                3            low  Female         3
# 7                  233                2            low  Female        48
# 8                  150                3            low  Female        11
# 9                  164                3         medium  Female        29
#
#    Weight_in_grams  Arrived_on_schedule
# 0             1233                    1
# 1             3088                    1
# 2             3374                    1
# 3             1177                    1
# 4             2484                    1
# 5             1417                    1
# 6             2371                    1
# 7             2804                    1
# 8             1861                    1
# 9             1187                    1

# %%
df.tail(10)
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 10989  10990               B             Ship                    5
# 10990  10991               C             Ship                    5
# 10991  10992               F             Ship                    5
# 10992  10993               D             Ship                    5
# 10993  10994               F             Ship                    5
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_Rating  Cost_of_the_Product  Prior_purchases Order_Priority  \
# 10989                1                  218                5         medium
# 10990                4                  219                6            low
# 10991                2                  261                5         medium
# 10992                1                  236                5         medium
# 10993                1                  257                6            low
# 10994                1                  252                5         medium
# 10995                1                  232                5         medium
# 10996                4                  242                5            low
# 10997                2                  223                6         medium
# 10998                5                  155                5            low
#
#        Gender  Discount  Weight_in_grams  Arrived_on_schedule
# 10989  Female         9             1603                    0
# 10990    Male         3             1098                    0
# 10991    Male         9             1227                    1
# 10992    Male         3             1906                    0
# 10993  Female         1             1150                    0
# 10994  Female         1             1538                    1
# 10995  Female         6             1247                    0
# 10996  Female         4             1155                    0
# 10997    Male         2             1210                    0
# 10998  Female         6             1639                    0

# %%
## checking the shape of the dataset
df.shape
# Out:
# (10999, 12)

# %%
df.dtypes
# Out:
# ID                      int64
# Warehouse_block        object
# Mode_of_Shipment       object
# Customer_care_calls     int64
# Customer_Rating         int64
# Cost_of_the_Product     int64
# Prior_purchases         int64
# Order_Priority         object
# Gender                 object
# Discount                int64
# Weight_in_grams         int64
# Arrived_on_schedule     int64
# dtype: object

# %%
## checking is there any null or missing values in the dataset 

df.isnull().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_Rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Order_Priority         0
# Gender                 0
# Discount               0
# Weight_in_grams        0
# Arrived_on_schedule    0
# dtype: int64

# %%
## checking is there any duplicate values in the dataset

df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10994    False
# 10995    False
# 10996    False
# 10997    False
# 10998    False
# Length: 10999, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0
